# %%
import pandas as pd
import numpy as np
import re
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
from datetime import datetime
import requests
import csv
import bs4
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas
import time

from selenium.webdriver.common.action_chains import ActionChains

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
options = Options()
options.add_argument('--headless')  # Chạy không hiển thị giao diện
options.add_argument('--disable-gpu')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument(f'user-agent={USER_AGENT}')
options.add_argument('--enable-unsafe-swiftshader')

service = Service() 
driver = webdriver.Chrome(service=service, options=options)

options.add_argument('--disable-software-rasterizer') 
action=ActionChains(driver)

# %%
USER_AGENT='Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'
REQUEST_HEADER={
    'User-Agent':USER_AGENT,
    'Accept-Language':'en-US,en;q=0.5',

}

# %%
urls=f"https://kital-tools.com/collections/needle-valves?gf_312953=brand_ASOH"
origin_link="https://kital-tools.com"
name="Needle Valves"
count_page=1

# %%
def get_link_to_file(url):
    driver.get(url)
    time.sleep(1.5) 
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    return soup

# %%
def get_data_from_web(index):##  Hàm lấy dữ liệu gốc
    url = f"{urls}?page={index}"
    driver.get(url)
    time.sleep(1.5) 
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')

    data_web = []
    products = soup.findAll('div', attrs={'class': 'spf-col-xl-2 spf-col-lg-3 spf-col-md-3 spf-col-sm-3 spf-col-6'})
    for product in products:
        name_tag = product.find("div", class_="h4 spf-product-card__title").find("a")
        name = name_tag.text.strip() if name_tag else "Không có tên"
        link = "https://kital-tools.com" + name_tag["href"] if name_tag else "Không có link"   
        data_web.append([index, name, link])
    return data_web

# %%
def get_data_from_link(url):
    if not url:
        print("Url Error")
        return None

    driver.get(url)
    time.sleep(1.5) 
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')

    # Ảnh
    img_tag = soup.find('img', class_='zoomImg')
    img_link = img_tag['src'] if img_tag else "No Image Found"

    # Tiêu đề
    title_tag = soup.find('h1', class_='product-single__title')
    title = title_tag.text.strip() if title_tag else "Không có tiêu đề"

    # Thông tin chi tiết
    product_info = soup.find('div', class_='product-single__meta')
    details = {}
    if product_info:
        for div in product_info.find_all('div'):
            text = div.text.strip()
            if text:
                parts = text.split("】")
                if len(parts) == 2:
                    key = parts[0].replace("【", "").strip()
                    value = parts[1].strip()
                    details[key] = value

    # Mô tả
    description_tag = soup.find('div', class_='product-single__description rte')
    description = description_tag.text.strip() if description_tag else " "

    # Giá
    price_tag = soup.find("span", class_='price-item price-item--regular')
    price = price_tag.text.strip() if price_tag else "None"
    time.sleep(1.5)
    return {
        "Product Name": title,
        "Image Link": img_link,
        **details,
        "Description": description,
        "Price": price
    }

# %%
def get_data_to_file():
    full_data = []
    for i in range(1,25):## lấy dữ liệu từ trang 1 đến trang 20
        ## lần 2 là: 21:31
        ## lần 3: 31:52
        full_data.extend(get_data_from_web(i))
        print(f"✅ Đã lấy dữ liệu trang {i}")

    df_web = pd.DataFrame(full_data, columns=["Page Index", "Product Name", "Product Link"])
    print(df_web.count())

    product_details_list = []

    for index, row in df_web.iterrows():
        if pd.notna(row["Product Link"]):  # Kiểm tra không phải None/NaN
            product_details = get_data_from_link(row["Product Link"])
            if not product_details:  # Nếu lỗi thì bỏ qua
                print(f"❌ Bỏ qua dòng {index} do không lấy được dữ liệu")
                continue
            product_details["Product Name"] = row["Product Name"]
            product_details["Product Link"] = row["Product Link"]
            product_details_list.append(product_details)
            print(f"✅ complete row {index}")
        else:
            print(f"⚠️ Link bị thiếu ở dòng {index}")
            continue

    print('✅ Hoàn tất crawl thông tin chi tiết')
    df_details = pd.DataFrame(product_details_list)

    # Kiểm tra xem cột có tồn tại trước khi merge
    missing_cols = {"Product Name", "Product Link"} - set(df_details.columns)
    if missing_cols:
        print(f"❌ Thiếu cột: {missing_cols} trong df_details. Không thể merge.")
        return

    df_final = df_web.merge(df_details, on=["Product Name", "Product Link"], how="left")
    df_final.to_csv(f"{name}.csv", index=False, encoding="utf-8-sig")
    print(f"🚀 Đã lưu {len(df_web)} sản phẩm vào {name}.csv")

# %%
urls=f"https://kital-tools.com/collections/drills"
   # https://kital-tools.com/collections/driver-
#https://kital-tools.com/collections/driver-bits?sort_by=relevance&q=Driver+Bits
origin_link="https://kital-tools.com"
name="Drill1_25"
count_page=280#sửa// lấy 20 trang đầu
## Thiếu trang 2 ,8,12
## Note có thể sai code như này ở trên là dấu ? hoặc & từ hàm (get_data_from_web)

# %%
get_data_to_file()
# Out:
# ✅ Đã lấy dữ liệu trang 1
# ✅ Đã lấy dữ liệu trang 2
# ✅ Đã lấy dữ liệu trang 3
# ✅ Đã lấy dữ liệu trang 4
# ✅ Đã lấy dữ liệu trang 5
# ✅ Đã lấy dữ liệu trang 6
# ✅ Đã lấy dữ liệu trang 7
# ✅ Đã lấy dữ liệu trang 8
# ✅ Đã lấy dữ liệu trang 9
# ✅ Đã lấy dữ liệu trang 10
# ✅ Đã lấy dữ liệu trang 11
# ✅ Đã lấy dữ liệu trang 12
# ✅ Đã lấy dữ liệu trang 13
# ✅ Đã lấy dữ liệu trang 14
# ✅ Đã lấy dữ liệu trang 15
# ✅ Đã lấy dữ liệu trang 16
# ✅ Đã lấy dữ liệu trang 17
# ✅ Đã lấy dữ liệu trang 18
# ✅ Đã lấy dữ liệu trang 19
# ✅ Đã lấy dữ liệu trang 20
# ✅ Đã lấy dữ liệu trang 21
# ✅ Đã lấy dữ liệu trang 22
# ✅ Đã lấy dữ liệu trang 23
# ✅ Đã lấy dữ liệu trang 24
# Page Index      1440
# Product Name    1440
# Product Link    1440
# dtype: int64
# ✅ complete row 0
# ✅ complete row 1
# ✅ complete row 2
# ✅ complete row 3
# ✅ complete row 4
# ✅ complete row 5
# ✅ complete row 6
# ✅ complete row 7
# ✅ complete row 8
# ✅ complete row 9
# ✅ complete row 10
# ✅ complete row 11
# ✅ complete row 12
# ✅ complete row 13
# ✅ complete row 14
# ✅ complete row 15
# ✅ complete row 16
# ✅ complete row 17
# ✅ complete row 18
# ✅ complete row 19
# ✅ complete row 20
# ✅ complete row 21
# ✅ complete row 22
# ✅ complete row 23
# ✅ complete row 24
# ✅ complete row 25
# ✅ complete row 26
# ✅ complete row 27
# ✅ complete row 28
# ✅ complete row 29
# ✅ complete row 30
# ✅ complete row 31
# ✅ complete row 32
# ✅ complete row 33
# ✅ complete row 34
# ✅ complete row 35
# ✅ complete row 36
# ✅ complete row 37
# ✅ complete row 38
# ✅ complete row 39
# ✅ complete row 40
# ✅ complete row 41
# ✅ complete row 42
# ✅ complete row 43
# ✅ complete row 44
# ✅ complete row 45
# ✅ complete row 46
# ✅ complete row 47
# ✅ complete row 48
# ✅ complete row 49
# ✅ complete row 50
# ✅ complete row 51
# ✅ complete row 52
# ✅ complete row 53
# ✅ complete row 54
# ✅ complete row 55
# ✅ complete row 56
# ✅ complete row 57
# ✅ complete row 58
# ✅ complete row 59
# ✅ complete row 60
# ✅ complete row 61
# ✅ complete row 62
# ✅ complete row 63
# ✅ complete row 64
# ✅ complete row 65
# ✅ complete row 66
# ✅ complete row 67
# ✅ complete row 68
# ✅ complete row 69
# ✅ complete row 70
# ✅ complete row 71
# ✅ complete row 72
# ✅ complete row 73
# ✅ complete row 74
# ✅ complete row 75
# ✅ complete row 76
# ✅ complete row 77
# ✅ complete row 78
# ✅ complete row 79
# ✅ complete row 80
# ✅ complete row 81
# ✅ complete row 82
# ✅ complete row 83
# ✅ complete row 84
# ✅ complete row 85
# ✅ complete row 86
# ✅ complete row 87
# ✅ complete row 88
# ✅ complete row 89
# ✅ complete row 90
# ✅ complete row 91
# ✅ complete row 92
# ✅ complete row 93
# ✅ complete row 94
# ✅ complete row 95
# ✅ complete row 96
# ✅ complete row 97
# ✅ complete row 98
# ✅ complete row 99
# ✅ complete row 100
# ✅ complete row 101
# ✅ complete row 102
# ✅ complete row 103
# ✅ complete row 104
# ✅ complete row 105
# ✅ complete row 106
# ✅ complete row 107
# ✅ complete row 108
# ✅ complete row 109
# ✅ complete row 110
# ✅ complete row 111
# ✅ complete row 112
# ✅ complete row 113
# ✅ complete row 114
# ✅ complete row 115
# ✅ complete row 116
# ✅ complete row 117
# ✅ complete row 118
# ✅ complete row 119
# ✅ complete row 120
# ✅ complete row 121
# ✅ complete row 122
# ✅ complete row 123
# ✅ complete row 124
# ✅ complete row 125
# ✅ complete row 126
# ✅ complete row 127
# ✅ complete row 128
# ✅ complete row 129
# ✅ complete row 130
# ✅ complete row 131
# ✅ complete row 132
# ✅ complete row 133
# ✅ complete row 134
# ✅ complete row 135
# ✅ complete row 136
# ✅ complete row 137
# ✅ complete row 138
# ✅ complete row 139
# ✅ complete row 140
# ✅ complete row 141
# ✅ complete row 142
# ✅ complete row 143
# ✅ complete row 144
# ✅ complete row 145
# ✅ complete row 146
# ✅ complete row 147
# ✅ complete row 148
# ✅ complete row 149
# ✅ complete row 150
# ✅ complete row 151
# ✅ complete row 152
# ✅ complete row 153
# ✅ complete row 154
# ✅ complete row 155
# ✅ complete row 156
# ✅ complete row 157
# ✅ complete row 158
# ✅ complete row 159
# ✅ complete row 160
# ✅ complete row 161
# ✅ complete row 162
# ✅ complete row 163
# ✅ complete row 164
# ✅ complete row 165
# ✅ complete row 166
# ✅ complete row 167
# ✅ complete row 168
# ✅ complete row 169
# ✅ complete row 170
# ✅ complete row 171
# ✅ complete row 172
# ✅ complete row 173
# ✅ complete row 174
# ✅ complete row 175
# ✅ complete row 176
# ✅ complete row 177
# ✅ complete row 178
# ✅ complete row 179
# ✅ complete row 180
# ✅ complete row 181
# ✅ complete row 182
# ✅ complete row 183
# ✅ complete row 184
# ✅ complete row 185
# ✅ complete row 186
# ✅ complete row 187
# ✅ complete row 188
# ✅ complete row 189
# ✅ complete row 190
# ✅ complete row 191
# ✅ complete row 192
# ✅ complete row 193
# ✅ complete row 194
# ✅ complete row 195
# ✅ complete row 196
# ✅ complete row 197
# ✅ complete row 198
# ✅ complete row 199
# ✅ complete row 200
# ✅ complete row 201
# ✅ complete row 202
# ✅ complete row 203
# ✅ complete row 204
# ✅ complete row 205
# ✅ complete row 206
# ✅ complete row 207
# ✅ complete row 208
# ✅ complete row 209
# ✅ complete row 210
# ✅ complete row 211
# ✅ complete row 212
# ✅ complete row 213
# ✅ complete row 214
# ✅ complete row 215
# ✅ complete row 216
# ✅ complete row 217
# ✅ complete row 218
# ✅ complete row 219
# ✅ complete row 220
# ✅ complete row 221
# ✅ complete row 222
# ✅ complete row 223
# ✅ complete row 224
# ✅ complete row 225
# ✅ complete row 226
# ✅ complete row 227
# ✅ complete row 228
# ✅ complete row 229
# ✅ complete row 230
# ✅ complete row 231
# ✅ complete row 232
# ✅ complete row 233
# ✅ complete row 234
# ✅ complete row 235
# ✅ complete row 236
# ✅ complete row 237
# ✅ complete row 238
# ✅ complete row 239
# ✅ complete row 240
# ✅ complete row 241
# ✅ complete row 242
# ✅ complete row 243
# ✅ complete row 244
# ✅ complete row 245
# ✅ complete row 246
# ✅ complete row 247
# ✅ complete row 248
# ✅ complete row 249
# ✅ complete row 250
# ✅ complete row 251
# ✅ complete row 252
# ✅ complete row 253
# ✅ complete row 254
# ✅ complete row 255
# ✅ complete row 256
# ✅ complete row 257
# ✅ complete row 258
# ✅ complete row 259
# ✅ complete row 260
# ✅ complete row 261
# ✅ complete row 262
# ✅ complete row 263
# ✅ complete row 264
# ✅ complete row 265
# ✅ complete row 266
# ✅ complete row 267
# ✅ complete row 268
# ✅ complete row 269
# ✅ complete row 270
# ✅ complete row 271
# ✅ complete row 272
# ✅ complete row 273
# ✅ complete row 274
# ✅ complete row 275
# ✅ complete row 276
# ✅ complete row 277
# ✅ complete row 278
# ✅ complete row 279
# ✅ complete row 280
# ✅ complete row 281
# ✅ complete row 282
# ✅ complete row 283
# ✅ complete row 284
# ✅ complete row 285
# ✅ complete row 286
# ✅ complete row 287
# ✅ complete row 288
# ✅ complete row 289
# ✅ complete row 290
# ✅ complete row 291
# ✅ complete row 292
# ✅ complete row 293
# ✅ complete row 294
# ✅ complete row 295
# ✅ complete row 296
# ✅ complete row 297
# ✅ complete row 298
# ✅ complete row 299
# ✅ complete row 300
# ✅ complete row 301
# ✅ complete row 302
# ✅ complete row 303
# ✅ complete row 304
# ✅ complete row 305
# ✅ complete row 306
# ✅ complete row 307
# ✅ complete row 308
# ✅ complete row 309
# ✅ complete row 310
# ✅ complete row 311
# ✅ complete row 312
# ✅ complete row 313
# ✅ complete row 314
# ✅ complete row 315
# ✅ complete row 316
# ✅ complete row 317
# ✅ complete row 318
# ✅ complete row 319
# ✅ complete row 320
# ✅ complete row 321
# ✅ complete row 322
# ✅ complete row 323
# ✅ complete row 324
# ✅ complete row 325
# ✅ complete row 326
# ✅ complete row 327
# ✅ complete row 328
# ✅ complete row 329
# ✅ complete row 330
# ✅ complete row 331
# ✅ complete row 332
# ✅ complete row 333
# ✅ complete row 334
# ✅ complete row 335
# ✅ complete row 336
# ✅ complete row 337
# ✅ complete row 338
# ✅ complete row 339
# ✅ complete row 340
# ✅ complete row 341
# ✅ complete row 342
# ✅ complete row 343
# ✅ complete row 344
# ✅ complete row 345
# ✅ complete row 346
# ✅ complete row 347
# ✅ complete row 348
# ✅ complete row 349
# ✅ complete row 350
# ✅ complete row 351
# ✅ complete row 352
# ✅ complete row 353
# ✅ complete row 354
# ✅ complete row 355
# ✅ complete row 356
# ✅ complete row 357
# ✅ complete row 358
# ✅ complete row 359
# ✅ complete row 360
# ✅ complete row 361
# ✅ complete row 362
# ✅ complete row 363
# ✅ complete row 364
# ✅ complete row 365
# ✅ complete row 366
# ✅ complete row 367
# ✅ complete row 368
# ✅ complete row 369
# ✅ complete row 370
# ✅ complete row 371
# ✅ complete row 372
# ✅ complete row 373
# ✅ complete row 374
# ✅ complete row 375
# ✅ complete row 376
# ✅ complete row 377
# ✅ complete row 378
# ✅ complete row 379
# ✅ complete row 380
# ✅ complete row 381
# ✅ complete row 382
# ✅ complete row 383
# ✅ complete row 384
# ✅ complete row 385
# ✅ complete row 386
# ✅ complete row 387
# ✅ complete row 388
# ✅ complete row 389
# ✅ complete row 390
# ✅ complete row 391
# ✅ complete row 392
# ✅ complete row 393
# ✅ complete row 394
# ✅ complete row 395
# ✅ complete row 396
# ✅ complete row 397
# ✅ complete row 398
# ✅ complete row 399
# ✅ complete row 400
# ✅ complete row 401
# ✅ complete row 402
# ✅ complete row 403
# ✅ complete row 404
# ✅ complete row 405
# ✅ complete row 406
# ✅ complete row 407
# ✅ complete row 408
# ✅ complete row 409
# ✅ complete row 410
# ✅ complete row 411
# ✅ complete row 412
# ✅ complete row 413
# ✅ complete row 414
# ✅ complete row 415
# ✅ complete row 416
# ✅ complete row 417
# ✅ complete row 418
# ✅ complete row 419
# ✅ complete row 420
# ✅ complete row 421
# ✅ complete row 422
